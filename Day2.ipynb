# %% [markdown]
# <a href="https://colab.research.google.com/github/davidr1008/Day2/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MATPLOT LIB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset('iris')

data.head(12)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa

# %%
data = sns.load_dataset('iris')

data.head(12)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa

# %%
plt.plot(data['sepal_width'])
plt.show()

# %%
plt.plot(data['petal_length'])
plt.title("Line Chart using Petel_Length")
plt.xlabel("Indexes")
plt.ylabel("Petel_Length")

plt.show()

# %%
plt.plot(data['sepal_width'])
plt.title("Iris Species", fontsize = 27)
plt.xlabel("Indexed") 
plt.ylabel("Sepel Width") 

plt.show()

# %%
plt.plot(data['sepal_width'], color = "green") #Selcting the column name from the dataset to plot
#plot() is the method used in matplotlib to plot any numerical data
plt.title("Iris Species", fontsize = 27) #Title of graph
plt.xlabel("Indexed") #Name to x-axis
plt.ylabel("Sepel Width") #Name for y- sxis

plt.show()

# %%
plt.plot(data['sepal_width'], color = "red") #Selcting the column name from the dataset to plot
plt.plot(data['sepal_length'], color = "green")
plt.plot(data['petal_length'], color = "black")
plt.plot(data['petal_width'], color = "orange")
#plot() is the method used in matplotlib to plot any numerical data
plt.title("Iris Species", fontsize = 27) #Title of graph
plt.xlabel("Indexed") #Name to x-axis
plt.ylabel("Multiple Features") #Name for y- sxis

plt.show()

# %%
plt.plot(data['sepal_width'],  color = "red", label = "Sepel Width") #Selcting the column name from the dataset to plot
plt.plot(data['sepal_length'], color = "green", label = "Sepel Length")
plt.plot(data['petal_length'],color = "black", label = "Petal Length")
plt.plot(data['petal_width'], color = "orange", label = "Petal Width")
#plot() is the method used in matplotlib to plot any numerical data
plt.title("Iris Species", fontsize = 27) #Title of graph
plt.xlabel("Indexed") #Name to x-axis
plt.ylabel("Multiple Features") #Name for y- sxis
plt.legend()
plt.show()

# %%
plt.figure(figsize= (10, 5))

plt.plot(data['sepal_width'],color = "orange" , label = "Sepel Width") #Selcting the column name from the dataset to plot
plt.plot(data['sepal_length'], color = "green", label = "Sepel Length")
plt.plot(data['petal_length'], color = "red", label = "Petal Length")
plt.plot(data['petal_width'],color = "black" , label = "Petal Width")
#plot() is the method used in matplotlib to plot any numerical data
plt.title("Iris Species", fontsize = 27) #Title of graph
plt.xlabel("Indexed") #Name to x-axis
plt.ylabel("Multiple Features") #Name for y- sxis
plt.legend()
plt.show()

# %%
plt.figure(figsize= (10, 5))
plt.plot(data['sepal_width'], color = "red", label = "Sepel Width", linestyle = '--') #Selcting the column name from the dataset to plot
plt.plot(data['sepal_length'], color = "green", label = "Sepel Length", linestyle = '--')
plt.plot(data['petal_length'],color = "black" , label = "Petal Length")
plt.plot(data['petal_width'], color = "orange", label = "Petal Width")
#plot() is the method used in matplotlib to plot any numerical data
plt.title("Iris Species", fontsize = 27) #Title of graph
plt.xlabel("Indexed") #Name to x-axis
plt.ylabel("Multiple Features") #Name for y- sxis
plt.legend()
plt.show()

# %%
plt.figure(figsize= (10, 5))
plt.plot(data['sepal_width'],color = "red" , label = "Sepel Width", linestyle = '--') #Selcting the column name from the dataset to plot
plt.plot(data['sepal_length'], color = "green", label = "Sepel Length", linestyle = '--')
plt.plot(data['petal_length'],color = "black" , label = "Petal Length", marker = '*')
plt.plot(data['petal_width'], color = "orange", label = "Petal Width", marker = '+')
#plot() is the method used in matplotlib to plot any numerical data
plt.title("Iris Species", fontsize = 27) #Title of graph
plt.xlabel("Indexed") #Name to x-axis
plt.ylabel("Multiple Features") #Name for y- sxis
plt.legend()
plt.show()

# %%
plt.figure(figsize= (10, 5))
plt.plot(data['sepal_width'], color = "black", label = "Sepel Width", linestyle = '--') #Selcting the column name from the dataset to plot
plt.plot(data['sepal_length'], color = "green", label = "Sepel Length", linestyle = '--')
plt.plot(data['petal_length'], color = "red", label = "Petal Length", marker = '*')
plt.plot(data['petal_width'], color = "orange", label = "Petal Width", marker = '+', linewidth = 5)
#plot() is the method used in matplotlib to plot any numerical data
plt.title("Iris Species", fontsize = 27) #Title of graph
plt.xlabel("Indexed") #Name to x-axis
plt.ylabel("Multiple Features") #Name for y- sxis
plt.legend()
plt.show()

# %%
plt.figure(figsize= (10, 5))

plt.grid()
plt.plot(data['sepal_width'], color = "black", label = "Sepel Width", linestyle = '--') #Selcting the column name from the dataset to plot
plt.plot(data['sepal_length'], color = "green", label = "Sepel Length", linestyle = '--')
plt.plot(data['petal_length'], color = "red", label = "Petal Length", marker = '*')
plt.plot(data['petal_width'], color = "orange", label = "Petal Width", marker = '+')
#plot() is the method used in matplotlib to plot any numerical data
plt.title("Iris Species", fontsize = 27) #Title of graph
plt.xlabel("Indexed") #Name to x-axis
plt.ylabel("Multiple Features") #Name for y- sxis
plt.legend()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.figure(figsize= (10, 5))
plt.grid()
plt.style.use('fivethirtyeight')
plt.plot(data['sepal_width'], color = "black", label = "Sepel Width", linestyle = '--') #Selcting the column name from the dataset to plot
plt.plot(data['sepal_length'], color = "green", label = "Sepel Length", linestyle = '--')
plt.plot(data['petal_length'], color = "red", label = "Petal Length", marker = '*')
plt.plot(data['petal_width'], color = "orange", label = "Petal Width", marker = '+',)
#plot() is the method used in matplotlib to plot any numerical data
plt.title("Iris Species", fontsize = 27) #Title of graph
plt.xlabel("Indexed") #Name to x-axis
plt.ylabel("Multiple Features") #Name for y- sxis
plt.legend()
plt.show()

# %%
plt.bar(data['species'], data['sepal_length'])
plt.bar(data['species'], data['sepal_width'])
plt.show()

# %%
tips = sns.load_dataset('tips')
tips.head(12)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4

# %%
#Histogram

plt.hist(tips['total_bill'], bins = 20, edgecolor = 'black')
plt.show()

# %%
day = tips.groupby('day')['total_bill'].sum().reset_index()

x = day['day']
y = day['total_bill']

explode = [0,0,0,0.1]
plt.pie(y, labels= x, explode = explode, autopct= "%1.1f%%", colors = ['red', 'blue', 'green', 'yellow'], wedgeprops= {'edgecolor' : "black"}, shadow = True, startangle = 90)
plt.show()

# %%
plt.boxplot(tips['total_bill'])

plt.show()

# %%
#Scatter Plot

plt.scatter(tips['total_bill'], tips['tip'])
plt.title("Scatter Plot ")
plt.xlabel("Total Bill")
plt.ylabel("Tip")

plt.show()

# %%
#Scatter Plot

plt.scatter(tips['total_bill'], tips['tip'], c = 'red')
plt.title("Scatter Plot ")
plt.xlabel("Total Bill")
plt.ylabel("Tip")

plt.show()

# %%
#Scatter Plot

plt.scatter(tips['total_bill'], tips['tip'], s = 100,c = tips['size'])
plt.title("Scatter Plot ")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
cbar = plt.colorbar()
cbar.set_label("Size")

plt.show()

# %%
sns.barplot(x = 'day', y='total_bill', data = tips)

# %%
sns.boxplot(y= "total_bill", data = tips)

# %%
sns.boxplot(x = 'day', y = "total_bill", data = tips)

# %%
#Scatter plt using seaborn

sns.scatterplot(x = "total_bill", y = 'tip', data = tips, palette= "summer", hue= 'size')

# %%
sns.swarmplot(x = "total_bill", y = "sex", data = tips)

# %%
sns.boxplot(x = 'sex', y = 'total_bill', data = tips)
sns.swarmplot(x = 'sex', y = 'total_bill', data = tips)

# %%
#Stripplot

sns.stripplot(x = 'sex', y = 'total_bill', data = tips, hue='sex')

# %%
#Violin plot

sns.violinplot(x = 'day', y = 'tip', data = tips, hue= "sex", split = True)
